# %%
import anndata as ad
import json
import polars
import hashlib

# %%
pmc_ps = ad.read_h5ad('./input/PMC_patch_seq.h5ad')

# %%
pmc_ps.obs[0:5]
# Out:
#                    Number             Slice        Date    Sample  \
# Cell
# 20171204_sample_2       1  20171204_slice_2  2017-12-04  sample 2
# 20171204_sample_4       2  20171204_slice_4  2017-12-04  sample 4
# 20171204_sample_5       3  20171204_slice_5  2017-12-04  sample 5
# 20171204_sample_6       4  20171204_slice_6  2017-12-04  sample 6
# 20171207_sample_1       5  20171207_slice_1  2017-12-07  sample 1
#
#                       donor_id Mouse date of birth  Mouse age  \
# Cell
# 20171204_sample_2  mouse_GTOKH          2017-10-29         36
# 20171204_sample_4  mouse_GTOKH          2017-10-29         36
# 20171204_sample_5  mouse_GTOKH          2017-10-29         36
# 20171204_sample_6  mouse_GTOKH          2017-10-29         36
# 20171207_sample_1  mouse_UGZSW          2017-09-18         80
#
#                             Mouse genotype Targeted layer Inferred layer  ...  \
# Cell                                                                      ...
# ...

# %%
pmc_ps.uns
# Out:
# {'cell_type_ontology_term_id_colors': array(['#1f77b4', '#ff7f0e', '#279e68'], dtype=object),
#  'schema_version': '3.1.0',
#  'title': 'All cells with electrophysiological recordings'}

# %%
output = polars.read_csv('./output/output/1695923608885.csv', comment_char='#')

# %%
output[0:5]
# Out:
# shape: (5, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ cell_id   ┆ class_lab ┆ class_nam ┆ class_boo ┆ … ┆ cluster_l ┆ cluster_n ┆ cluster_a ┆ cluster_ │
# │ ---       ┆ el        ┆ e         ┆ tstrappin ┆   ┆ abel      ┆ ame       ┆ lias      ┆ bootstra │
# │ str       ┆ ---       ┆ ---       ┆ g_probabi ┆   ┆ ---       ┆ ---       ┆ ---       ┆ pping_pr │
# │           ┆ str       ┆ str       ┆ lity      ┆   ┆ str       ┆ str       ┆ i64       ┆ obabilit │
# │           ┆           ┆           ┆ ---       ┆   ┆           ┆           ┆           ┆ …        │
# │           ┆           ┆           ┆ f64       ┆   ┆           ┆           ┆           ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# ...

# %% [markdown]
# Aims:
#  - Generate sample labelset JSON - can curate by hand except fot cell_ids
#  - Generate hash for
#  - Illustrate what this would look like in AnnData obs with confidence.

# %%
example_annotation_transfer = {
  "dataset": "cellxgene_dataset:"
  "labelsets": [
    { "name": "MapMyCells_10x_mouse_subclass",
      "description": "Annotation transfer from 10X whole mouse brain CCN20230722 using Map My Cells.",
      "annotation_method": "algorithmic",
      "automated_annotation": {
          "algorithm_name": "Map My Cells - hierarchical mapping",
          "source_taxonomy": "CCN20230722",
      }
    }
    ],
  "annotations": [
       { "labelset": "map_my_cells_CCN20230722", 

         "cell_label": "004 L6 IT CTX Glut",
         "cell_ontology_term": "",
         "cell_ontology_term_id": "",
         "annotation_transfer": {
           "source_accession": "CS20230722_SUBC_004",
         }
        "cell_ids": ["20190501_sample_12", "20190506_sample_4", "20180704_sample_4", "20190110_sample_6", "20190719_sample_6", 
                     "20190821_sample_2", "20190821_sample_7", "20190823_sample_7", "20190219_sample_8", "20190320_sample_4", 
                     "20190422_sample_7", "20190211_sample_2", "20190211_sample_4", "20190222_sample_3", "20190320_sample_9", 
                     "20190328_sample_8", "20190403_sample_5", "20190409_sample_9", "20190409_sample_11", "20190412_sample_3", 
                     "20190415_sample_4", "20190415_sample_10", "20190416_sample_6", "20190416_sample_9", "20190424_sample_6", 
                     "20190425_sample_1", "20190425_sample_7", "20190425_sample_16", "20190829_sample_3", "20190830_sample_1", 
                     "20180820_sample_2", "20190222_sample_8", "20190927_sample_4", "20191106_sample_3", "20190204_sample_2", 
                     "20190604_sample_12", "20190708_sample_8", "20190830_sample_2", "20190322_sample_1", "20190325_sample_3", 
                     "20190327_sample_2", "20190418_sample_5", "20190821_sample_5", "20190321_sample_4", "20190325_sample_7", 
                     "20190423_sample_1", "20190611_sample_11", "20171204_sample_4", "20171207_sample_7", "20180102_sample_2", 
                     "20180105_sample_6", "20180110_sample_2", "20180115_sample_9", "20180118_sample_1", "20180208_sample_4"],
        "cells": [{'cell_id': '20171204_sample_4', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20171207_sample_7', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20180102_sample_2', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20180105_sample_6', 'subclass_bootstrapping_probability': 0.98},
 {'cell_id': '20180110_sample_2', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20180115_sample_9', 'subclass_bootstrapping_probability': 0.55},
 {'cell_id': '20180118_sample_1', 'subclass_bootstrapping_probability': 0.62},
 {'cell_id': '20180208_sample_4', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20180704_sample_4', 'subclass_bootstrapping_probability': 0.79},
 {'cell_id': '20180820_sample_2', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190110_sample_6', 'subclass_bootstrapping_probability': 0.57},
 {'cell_id': '20190204_sample_2', 'subclass_bootstrapping_probability': 0.96},
 {'cell_id': '20190211_sample_2', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190211_sample_4', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190219_sample_8', 'subclass_bootstrapping_probability': 0.92},
 {'cell_id': '20190222_sample_3', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190222_sample_8', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190320_sample_4', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190320_sample_9', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190321_sample_4', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190322_sample_1', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190325_sample_3', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190325_sample_7', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190327_sample_2', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190328_sample_8', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190403_sample_5', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190409_sample_9', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190409_sample_11', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190412_sample_3', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190415_sample_4', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190415_sample_10', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190416_sample_6', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190416_sample_9', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190418_sample_5', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190422_sample_7', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190423_sample_1', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190424_sample_6', 'subclass_bootstrapping_probability': 0.98},
 {'cell_id': '20190425_sample_1', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190425_sample_7', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190425_sample_16', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190501_sample_12', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190506_sample_4', 'subclass_bootstrapping_probability': 0.55},
 {'cell_id': '20190604_sample_12', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190611_sample_11', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190708_sample_8', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190719_sample_6', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190821_sample_2', 'subclass_bootstrapping_probability': 0.68},
 {'cell_id': '20190821_sample_5', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190821_sample_7', 'subclass_bootstrapping_probability': 0.99},
 {'cell_id': '20190823_sample_7', 'subclass_bootstrapping_probability': 0.74},
 {'cell_id': '20190829_sample_3', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190830_sample_1', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190830_sample_2', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20190927_sample_4', 'subclass_bootstrapping_probability': 1.0},
 {'cell_id': '20191106_sample_3', 'subclass_bootstrapping_probability': 1.0}]
        ]
}
# Out:
#   Cell In[20], line 3
#     "labelsets": [
#                ^
# SyntaxError: invalid syntax

# %%
fu = output.filter(polars.col("subclass_name") == "004 L6 IT CTX Glut")[["cell_id", "subclass_bootstrapping_probability"]].to_dicts()

# %%
json.dumps
# Out:
# [{'cell_id': '20171204_sample_4', 'subclass_bootstrapping_probability': 1.0},
#  {'cell_id': '20171207_sample_7', 'subclass_bootstrapping_probability': 1.0},
#  {'cell_id': '20180102_sample_2', 'subclass_bootstrapping_probability': 1.0},
#  {'cell_id': '20180105_sample_6', 'subclass_bootstrapping_probability': 0.98},
#  {'cell_id': '20180110_sample_2', 'subclass_bootstrapping_probability': 1.0},
#  {'cell_id': '20180115_sample_9', 'subclass_bootstrapping_probability': 0.55},
#  {'cell_id': '20180118_sample_1', 'subclass_bootstrapping_probability': 0.62},
#  {'cell_id': '20180208_sample_4', 'subclass_bootstrapping_probability': 1.0},
#  {'cell_id': '20180704_sample_4', 'subclass_bootstrapping_probability': 0.79},
#  {'cell_id': '20180820_sample_2', 'subclass_bootstrapping_probability': 1.0},
#  {'cell_id': '20190110_sample_6', 'subclass_bootstrapping_probability': 0.57},
#  {'cell_id': '20190204_sample_2', 'subclass_bootstrapping_probability': 0.96},
# ...

# %%
json.dumps(fu, prett)
# Out:
# '[{"cell_id": "20171204_sample_4", "subclass_bootstrapping_probability": 1.0}, {"cell_id": "20171207_sample_7", "subclass_bootstrapping_probability": 1.0}, {"cell_id": "20180102_sample_2", "subclass_bootstrapping_probability": 1.0}, {"cell_id": "20180105_sample_6", "subclass_bootstrapping_probability": 0.98}, {"cell_id": "20180110_sample_2", "subclass_bootstrapping_probability": 1.0}, {"cell_id": "20180115_sample_9", "subclass_bootstrapping_probability": 0.55}, {"cell_id": "20180118_sample_1", "subclass_bootstrapping_probability": 0.62}, {"cell_id": "20180208_sample_4", "subclass_bootstrapping_probability": 1.0}, {"cell_id": "20180704_sample_4", "subclass_bootstrapping_probability": 0.79}, {"cell_id": "20180820_sample_2", "subclass_bootstrapping_probability": 1.0}, {"cell_id": "20190110_sample_6", "subclass_bootstrapping_probability": 0.57}, {"cell_id": "20190204_sample_2", "subclass_bootstrapping_probability": 0.96}, {"cell_id": "20190211_sample_2", "subclass_bootstrapping_probabili
# ...

# %%
cell_ids = ["20190501_sample_12", "20190506_sample_4", "20180704_sample_4", "20190110_sample_6", "20190719_sample_6",
                     "20190821_sample_2", "20190821_sample_7", "20190823_sample_7", "20190219_sample_8", "20190320_sample_4",
                     "20190422_sample_7", "20190211_sample_2", "20190211_sample_4", "20190222_sample_3", "20190320_sample_9",
                     "20190328_sample_8", "20190403_sample_5", "20190409_sample_9", "20190409_sample_11", "20190412_sample_3",
                     "20190415_sample_4", "20190415_sample_10", "20190416_sample_6", "20190416_sample_9", "20190424_sample_6",
                     "20190425_sample_1", "20190425_sample_7", "20190425_sample_16", "20190829_sample_3", "20190830_sample_1",
                     "20180820_sample_2", "20190222_sample_8", "20190927_sample_4", "20191106_sample_3", "20190204_sample_2",
                     "20190604_sample_12", "20190708_sample_8", "20190830_sample_2", "20190322_sample_1", "20190325_sample_3",
                     "20190327_sample_2", "20190418_sample_5", "20190821_sample_5", "20190321_sample_4", "20190325_sample_7",
                     "20190423_sample_1", "20190611_sample_11", "20171204_sample_4", "20171207_sample_7", "20180102_sample_2",
                     "20180105_sample_6", "20180110_sample_2", "20180115_sample_9", "20180118_sample_1", "20180208_sample_4"]

# %%
cell_id_list = list(cell_ids)
cell_id_list.sort()
cell_id_list
barcodes = ".".join(cell_id_list)
barcodes
# Out:
# '20171204_sample_4.20171207_sample_7.20180102_sample_2.20180105_sample_6.20180110_sample_2.20180115_sample_9.20180118_sample_1.20180208_sample_4.20180704_sample_4.20180820_sample_2.20190110_sample_6.20190204_sample_2.20190211_sample_2.20190211_sample_4.20190219_sample_8.20190222_sample_3.20190222_sample_8.20190320_sample_4.20190320_sample_9.20190321_sample_4.20190322_sample_1.20190325_sample_3.20190325_sample_7.20190327_sample_2.20190328_sample_8.20190403_sample_5.20190409_sample_11.20190409_sample_9.20190412_sample_3.20190415_sample_10.20190415_sample_4.20190416_sample_6.20190416_sample_9.20190418_sample_5.20190422_sample_7.20190423_sample_1.20190424_sample_6.20190425_sample_1.20190425_sample_16.20190425_sample_7.20190501_sample_12.20190506_sample_4.20190604_sample_12.20190611_sample_11.20190708_sample_8.20190719_sample_6.20190821_sample_2.20190821_sample_5.20190821_sample_7.20190823_sample_7.20190829_sample_3.20190830_sample_1.20190830_sample_2.20190927_sample_4.20191106_sample_3'

# %%
blake_hasher = hashlib.blake2b(str.encode(barcodes), digest_size=6)
bhash = blake_hasher.hexdigest()
bhash
# Out:
# '234d8d6eb87f'
